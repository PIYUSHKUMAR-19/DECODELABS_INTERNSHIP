# %%
import pandas as pd

# %%
df = pd.read_excel("Dataset/Dataset for Data Analytics (2).xlsx")

# %%
import sys
!"{sys.executable}" -m pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel("Dataset/Dataset for Data Analytics (2).xlsx")

# %%
df.head()
# Out:
#      OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004 2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   str
#  1   Date             1200 non-null   datetime64[us]
#  2   CustomerID       1200 non-null   str
#  3   Product          1200 non-null   str
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   str
#  7   PaymentMethod    1200 non-null   str
#  8   OrderStatus      1200 non-null   str
#  9   TrackingNumber   1200 non-null   str
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    str
#  12  ReferralSource   1200 non-null   str
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(9)
# memory usage: 215.1 KB

# %%
df.describe()
# Out:
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %%
df.shape
# Out:
# (1200, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   str
#  1   Date             1200 non-null   datetime64[us]
#  2   CustomerID       1200 non-null   str
#  3   Product          1200 non-null   str
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   str
#  7   PaymentMethod    1200 non-null   str
#  8   OrderStatus      1200 non-null   str
#  9   TrackingNumber   1200 non-null   str
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    str
#  12  ReferralSource   1200 non-null   str
#  13  TotalPrice       1200 non-null   float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(9)
# memory usage: 215.1 KB

# %%
df.isnull().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
df.isnull()
# Out:
#       OrderID   Date  CustomerID  Product  Quantity  UnitPrice  \
# 0       False  False       False    False     False      False
# 1       False  False       False    False     False      False
# 2       False  False       False    False     False      False
# 3       False  False       False    False     False      False
# 4       False  False       False    False     False      False
# ...       ...    ...         ...      ...       ...        ...
# 1195    False  False       False    False     False      False
# 1196    False  False       False    False     False      False
# 1197    False  False       False    False     False      False
# 1198    False  False       False    False     False      False
# 1199    False  False       False    False     False      False
#
#       ShippingAddress  PaymentMethod  OrderStatus  TrackingNumber  \
# 0               False          False        False           False
# 1               False          False        False           False
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Length: 1200, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                       Date     Quantity    UnitPrice  ItemsInCart   TotalPrice
# count                 1200  1200.000000  1200.000000  1200.000000  1200.000000
# mean   2024-03-22 16:58:48     2.945833   356.412750     5.485000  1053.968300
# min    2023-01-01 00:00:00     1.000000    11.390000     1.000000    11.390000
# 25%    2023-08-03 18:00:00     2.000000   186.062500     4.000000   410.520000
# 50%    2024-03-23 00:00:00     3.000000   364.210000     5.000000   823.615000
# 75%    2024-11-08 12:00:00     4.000000   521.570000     7.000000  1578.475000
# max    2025-06-30 00:00:00     5.000000   699.930000    10.000000  3456.400000
# std                    NaN     1.407557   197.177146     2.281983   819.856558

# %%
df.nunique()
# Out:
# OrderID            1200
# Date                671
# CustomerID         1189
# Product               7
# Quantity              5
# UnitPrice          1193
# ShippingAddress     655
# PaymentMethod         5
# OrderStatus           5
# TrackingNumber     1200
# ItemsInCart          10
# CouponCode            3
# ReferralSource        5
# TotalPrice         1195
# dtype: int64

# %%
df["Product"].value_counts()
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
df["OrderID"].value_counts()
# Out:
# OrderID
# ORD200000    1
# ORD200001    1
# ORD200002    1
# ORD200003    1
# ORD200004    1
#             ..
# ORD201195    1
# ORD201196    1
# ORD201197    1
# ORD201198    1
# ORD201199    1
# Name: count, Length: 1200, dtype: int64

# %%
df["Date"].value_counts()
# Out:
# Date
# 2023-08-20    8
# 2024-04-07    7
# 2024-12-19    6
# 2024-11-24    6
# 2025-03-15    6
#              ..
# 2024-08-17    1
# 2025-06-16    1
# 2024-03-04    1
# 2023-07-13    1
# 2024-08-22    1
# Name: count, Length: 671, dtype: int64

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %%
df["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
df["ReferralSource"].value_counts()
# Out:
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %%
df["CouponCode"].value_counts()
# Out:
# CouponCode
# FREESHIP    313
# WINTER15    292
# SAVE10      286
# Name: count, dtype: int64

# %%
df["TotalPrice"].count()
# Out:
# np.int64(1200)

# %%
df["TotalPrice"].mean()
# Out:
# np.float64(1053.9683)

# %%
df["TotalPrice"].median()
# Out:
# np.float64(823.615)

# %%
print("Count:", df["Quantity"].count())
print("Mean:", df["Quantity"].mean())
print("Median:", df["Quantity"].median())
print("Minimum:", df["Quantity"].min())
print("Maximum:", df["Quantity"].max())
# Out:
# Count: 1200
# Mean: 2.9458333333333333
# Median: 3.0
# Minimum: 1
# Maximum: 5

# %%
print("Count:", df["UnitPrice"].count())
print("Mean:", df["UnitPrice"].mean())
print("Median:", df["UnitPrice"].median())
print("Minimum:", df["UnitPrice"].min())
print("Maximum:", df["UnitPrice"].max())
# Out:
# Count: 1200
# Mean: 356.41275
# Median: 364.21
# Minimum: 11.39
# Maximum: 699.93

# %%
print("Count:", df["ItemsInCart"].count())
print("Mean:", df["ItemsInCart"].mean())
print("Median:", df["ItemsInCart"].median())
print("Minimum:", df["ItemsInCart"].min())
print("Maximum:", df["ItemsInCart"].max())
# Out:
# Count: 1200
# Mean: 5.485
# Median: 5.0
# Minimum: 1
# Maximum: 10

# %%
print("Minimum Date:", df["Date"].min())
print("Maximum Date:", df["Date"].max())
print("Number of Unique Dates:", df["Date"].nunique())
# Out:
# Minimum Date: 2023-01-01 00:00:00
# Maximum Date: 2025-06-30 00:00:00
# Number of Unique Dates: 671

# %%
df["ItemsInCart"].value_counts()
# Out:
# ItemsInCart
# 5     191
# 6     190
# 4     163
# 7     151
# 8     129
# 3     123
# 9      79
# 2      78
# 1      50
# 10     46
# Name: count, dtype: int64

# %%
df["ItemsInCart"].value_counts().sort_index()
# Out:
# ItemsInCart
# 1      50
# 2      78
# 3     123
# 4     163
# 5     191
# 6     190
# 7     151
# 8     129
# 9      79
# 10     46
# Name: count, dtype: int64

# %%
df["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %%
product_count=df["Product"].value_counts()
print(product_count)
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %%
df["TotalPrice"].describe()
# Out:
# count    1200.000000
# mean     1053.968300
# std       819.856558
# min        11.390000
# 25%       410.520000
# 50%       823.615000
# 75%      1578.475000
# max      3456.400000
# Name: TotalPrice, dtype: float64

# %%
Q1 = df["TotalPrice"].quantile(0.25)
Q3 = df["TotalPrice"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Q1: 410.52
# Q3: 1578.475
# IQR: 1167.955
# Lower Limit: -1341.4125
# Upper Limit: 3330.4075

# %%
outliers = df[
    (df["TotalPrice"] < lower_limit) |
    (df["TotalPrice"] > upper_limit)
]

print("Number of Outliers:", len(outliers))
print(outliers)
# Out:
# Number of Outliers: 8
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 107   ORD200107 2023-03-27     C16775  Printer         5     670.75
# 326   ORD200326 2024-07-01     C65986   Laptop         5     670.48
# 328   ORD200328 2023-02-28     C18404   Tablet         5     674.04
# 469   ORD200469 2023-11-26     C13877    Chair         5     676.98
# 632   ORD200632 2023-05-02     C67260   Laptop         5     678.16
# 789   ORD200789 2023-08-17     C57276   Tablet         5     691.28
# 1065  ORD201065 2023-10-30     C47778  Printer         5     666.80
# 1122  ORD201122 2023-06-07     C38840  Monitor         5     678.19
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 107      848 Main St     Gift Card     Shipped    TRK34392124            8
# 326      273 Main St     Gift Card    Returned    TRK98353867            5
# 328      546 Main St        Online   Cancelled    TRK89401624            7
# ...

# %%
outliers
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 107   ORD200107 2023-03-27     C16775  Printer         5     670.75
# 326   ORD200326 2024-07-01     C65986   Laptop         5     670.48
# 328   ORD200328 2023-02-28     C18404   Tablet         5     674.04
# 469   ORD200469 2023-11-26     C13877    Chair         5     676.98
# 632   ORD200632 2023-05-02     C67260   Laptop         5     678.16
# 789   ORD200789 2023-08-17     C57276   Tablet         5     691.28
# 1065  ORD201065 2023-10-30     C47778  Printer         5     666.80
# 1122  ORD201122 2023-06-07     C38840  Monitor         5     678.19
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 107      848 Main St     Gift Card     Shipped    TRK34392124            8
# 326      273 Main St     Gift Card    Returned    TRK98353867            5
# 328      546 Main St        Online   Cancelled    TRK89401624            7
# ...

# %%
numerical_columns = ["Quantity", "UnitPrice", "ItemsInCart"]

for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower_limit) |
        (df[col] > upper_limit)
    ]

    print(f"\nColumn: {col}")
    print("Lower Limit:", lower_limit)
    print("Upper Limit:", upper_limit)
    print("Number of Outliers:", len(outliers))
# Out:
# Column: Quantity
# Lower Limit: -1.0
# Upper Limit: 7.0
# Number of Outliers: 0
#
# Column: UnitPrice
# Lower Limit: -317.1987499999999
# Upper Limit: 1024.8312499999997
# Number of Outliers: 0
#
# Column: ItemsInCart
# Lower Limit: -0.5
# Upper Limit: 11.5
# Number of Outliers: 0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.boxplot(df["TotalPrice"])

plt.title("Boxplot of TotalPrice")
plt.ylabel("Total Price")

plt.show()

# %%
outliers[[
    "OrderID",
    "Date",
    "CustomerID",
    "Product",
    "Quantity",
    "UnitPrice",
    "PaymentMethod",
    "OrderStatus",
    "ItemsInCart",
    "TotalPrice"
]]
# Out:
# Empty DataFrame
# Columns: [OrderID, Date, CustomerID, Product, Quantity, UnitPrice, PaymentMethod, OrderStatus, ItemsInCart, TotalPrice]
# Index: []

# %%
Q1 = df["TotalPrice"].quantile(0.25)
Q3 = df["TotalPrice"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

totalprice_outliers = df[
    (df["TotalPrice"] < lower_limit) |
    (df["TotalPrice"] > upper_limit)
]

totalprice_outliers[[
    "OrderID",
    "Date",
    "CustomerID",
    "Product",
    "Quantity",
    "UnitPrice",
    "PaymentMethod",
    "OrderStatus",
    "ItemsInCart",
    "TotalPrice"
]]
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 107   ORD200107 2023-03-27     C16775  Printer         5     670.75
# 326   ORD200326 2024-07-01     C65986   Laptop         5     670.48
# 328   ORD200328 2023-02-28     C18404   Tablet         5     674.04
# 469   ORD200469 2023-11-26     C13877    Chair         5     676.98
# 632   ORD200632 2023-05-02     C67260   Laptop         5     678.16
# 789   ORD200789 2023-08-17     C57276   Tablet         5     691.28
# 1065  ORD201065 2023-10-30     C47778  Printer         5     666.80
# 1122  ORD201122 2023-06-07     C38840  Monitor         5     678.19
#
#      PaymentMethod OrderStatus  ItemsInCart  TotalPrice
# 107      Gift Card     Shipped            8     3353.75
# 326      Gift Card    Returned            5     3352.40
# 328         Online   Cancelled            7     3370.20
# 469           Cash   Cancelled            5     3384.90
# 632      Gift Card   Delivered            7     3390.80
# ...

# %%
totalprice_outliers["CalculatedPrice"] = (
    totalprice_outliers["Quantity"] * totalprice_outliers["UnitPrice"]
)

totalprice_outliers[[
    "OrderID",
    "Product",
    "Quantity",
    "UnitPrice",
    "CalculatedPrice",
    "TotalPrice"
]]
# Out:
#         OrderID  Product  Quantity  UnitPrice  CalculatedPrice  TotalPrice
# 107   ORD200107  Printer         5     670.75          3353.75     3353.75
# 326   ORD200326   Laptop         5     670.48          3352.40     3352.40
# 328   ORD200328   Tablet         5     674.04          3370.20     3370.20
# 469   ORD200469    Chair         5     676.98          3384.90     3384.90
# 632   ORD200632   Laptop         5     678.16          3390.80     3390.80
# 789   ORD200789   Tablet         5     691.28          3456.40     3456.40
# 1065  ORD201065  Printer         5     666.80          3334.00     3334.00
# 1122  ORD201122  Monitor         5     678.19          3390.95     3390.95

# %%
totalprice_outliers["Product"].value_counts()
# Out:
# Product
# Printer    2
# Laptop     2
# Tablet     2
# Chair      1
# Monitor    1
# Name: count, dtype: int64

# %%
outlier_percentage = (
    len(totalprice_outliers) / len(df)
) * 100

print("Total Orders:", len(df))
print("TotalPrice Outliers:", len(totalprice_outliers))
print("Outlier Percentage:", round(outlier_percentage, 2), "%")
# Out:
# Total Orders: 1200
# TotalPrice Outliers: 8
# Outlier Percentage: 0.67 %

# %%
correlation_matrix = df[
    ["Quantity", "UnitPrice", "ItemsInCart", "TotalPrice"]
].corr()

correlation_matrix
# Out:
#              Quantity  UnitPrice  ItemsInCart  TotalPrice
# Quantity     1.000000   0.014553     0.650061    0.615251
# UnitPrice    0.014553   1.000000     0.000602    0.717081
# ItemsInCart  0.650061   0.000602     1.000000    0.392540
# TotalPrice   0.615251   0.717081     0.392540    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix of Numerical Variables")
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["TotalPrice"], bins=30)

plt.title("Distribution of TotalPrice")
plt.xlabel("Total Price")
plt.ylabel("Number of Orders")

plt.show()

# %%
monthly_orders = df.groupby(
    df["Date"].dt.to_period("M")
).size()

monthly_orders
# Out:
# Date
# 2023-01    47
# 2023-02    37
# 2023-03    43
# 2023-04    31
# 2023-05    49
# 2023-06    45
# 2023-07    44
# 2023-08    51
# 2023-09    29
# 2023-10    47
# 2023-11    41
# 2023-12    46
# 2024-01    32
# 2024-02    32
# 2024-03    36
# 2024-04    50
# 2024-05    34
# 2024-06    53
# 2024-07    43
# 2024-08    28
# 2024-09    44
# 2024-10    31
# 2024-11    35
# 2024-12    41
# 2025-01    27
# 2025-02    37
# 2025-03    49
# 2025-04    32
# 2025-05    37
# 2025-06    49
# Freq: M, dtype: int64

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    monthly_orders.index.astype(str),
    monthly_orders.values,
    marker="o"
)

plt.title("Monthly Order Trend")
plt.xlabel("Month")
plt.ylabel("Number of Orders")

plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
monthly_sales = df.groupby(
    df["Date"].dt.to_period("M")
)["TotalPrice"].sum()

monthly_sales
# Out:
# Date
# 2023-01    56685.75
# 2023-02    40117.66
# 2023-03    48609.37
# 2023-04    27751.71
# 2023-05    63836.84
# 2023-06    49500.19
# 2023-07    42820.66
# 2023-08    54352.14
# 2023-09    29526.67
# 2023-10    52607.85
# 2023-11    43079.67
# 2023-12    43754.73
# 2024-01    38528.08
# 2024-02    36909.57
# 2024-03    36030.90
# 2024-04    49613.14
# 2024-05    27909.11
# 2024-06    68068.54
# 2024-07    42963.98
# 2024-08    31991.07
# 2024-09    39794.98
# 2024-10    37226.97
# 2024-11    32413.76
# 2024-12    38785.77
# 2025-01    29099.40
# 2025-02    35317.55
# 2025-03    39200.66
# 2025-04    31821.20
# 2025-05    43396.64
# 2025-06    53047.40
# Freq: M, Name: TotalPrice, dtype: float64

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    monthly_sales.index.astype(str),
    monthly_sales.values,
    marker="o"
)

plt.title("Monthly Total Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
monthly_summary = pd.DataFrame({
    "Total_Orders": monthly_orders,
    "Total_Sales": monthly_sales
})

monthly_summary
# Out:
#          Total_Orders  Total_Sales
# Date
# 2023-01            47     56685.75
# 2023-02            37     40117.66
# 2023-03            43     48609.37
# 2023-04            31     27751.71
# 2023-05            49     63836.84
# 2023-06            45     49500.19
# 2023-07            44     42820.66
# 2023-08            51     54352.14
# 2023-09            29     29526.67
# 2023-10            47     52607.85
# 2023-11            41     43079.67
# 2023-12            46     43754.73
# 2024-01            32     38528.08
# 2024-02            32     36909.57
# 2024-03            36     36030.90
# 2024-04            50     49613.14
# 2024-05            34     27909.11
# 2024-06            53     68068.54
# 2024-07            43     42963.98
# 2024-08            28     31991.07
# 2024-09            44     39794.98
# 2024-10            31     37226.97
# 2024-11            35     32413.76
# 2024-12            41     38785.77
# 2025-01            27     29099.40
# ...

# %%
monthly_summary["Average_Order_Value"] = (
    monthly_summary["Total_Sales"] /
    monthly_summary["Total_Orders"]
)

monthly_summary
# Out:
#          Total_Orders  Total_Sales  Average_Order_Value
# Date
# 2023-01            47     56685.75          1206.079787
# 2023-02            37     40117.66          1084.261081
# 2023-03            43     48609.37          1130.450465
# 2023-04            31     27751.71           895.216452
# 2023-05            49     63836.84          1302.792653
# 2023-06            45     49500.19          1100.004222
# 2023-07            44     42820.66           973.196818
# 2023-08            51     54352.14          1065.728235
# 2023-09            29     29526.67          1018.161034
# 2023-10            47     52607.85          1119.315957
# 2023-11            41     43079.67          1050.723659
# 2023-12            46     43754.73           951.189783
# 2024-01            32     38528.08          1204.002500
# 2024-02            32     36909.57          1153.424062
# 2024-03            36     36030.90          1000.858333
# 2024-04            50     49613.14           992.262800
# ...

# %%
overall_aov = df["TotalPrice"].sum() / df["OrderID"].nunique()

print("Overall Average Order Value:", round(overall_aov, 2))
# Out:
# Overall Average Order Value: 1053.97

# %%
top_10_orders = df.nlargest(10, "TotalPrice")

top_10_orders[[
    "OrderID",
    "Date",
    "Product",
    "Quantity",
    "UnitPrice",
    "ItemsInCart",
    "TotalPrice"
]]
# Out:
#         OrderID       Date  Product  Quantity  UnitPrice  ItemsInCart  \
# 789   ORD200789 2023-08-17   Tablet         5     691.28           10
# 1122  ORD201122 2023-06-07  Monitor         5     678.19            8
# 632   ORD200632 2023-05-02   Laptop         5     678.16            7
# 469   ORD200469 2023-11-26    Chair         5     676.98            5
# 328   ORD200328 2023-02-28   Tablet         5     674.04            7
# 107   ORD200107 2023-03-27  Printer         5     670.75            8
# 326   ORD200326 2024-07-01   Laptop         5     670.48            5
# 1065  ORD201065 2023-10-30  Printer         5     666.80            7
# 1031  ORD201031 2023-02-28    Phone         5     664.51            8
# 463   ORD200463 2023-05-26   Laptop         5     662.78            9
#
#       TotalPrice
# 789      3456.40
# 1122     3390.95
# 632      3390.80
# 469      3384.90
# 328      3370.20
# 107      3353.75
# 326      3352.40
# 1065     3334.00
# 1031     3322.55
# ...

# %%
top_10_orders["Product"].value_counts()
# Out:
# Product
# Laptop     3
# Tablet     2
# Printer    2
# Monitor    1
# Chair      1
# Phone      1
# Name: count, dtype: int64

# %%
top_10_average = top_10_orders["TotalPrice"].mean()
overall_average = df["TotalPrice"].mean()

print("Top 10 Average Order Value:", round(top_10_average, 2))
print("Overall Average Order Value:", round(overall_average, 2))
print(
    "Top 10 are",
    round(top_10_average / overall_average, 2),
    "times higher than overall average"
)
# Out:
# Top 10 Average Order Value: 3366.98
# Overall Average Order Value: 1053.97
# Top 10 are 3.19 times higher than overall average

# %%
product_sales = df.groupby("Product")["TotalPrice"].sum().sort_values(
    ascending=False
)

product_sales
# Out:
# Product
# Chair      195620.11
# Printer    195612.61
# Laptop     192126.56
# Tablet     186568.95
# Monitor    175651.41
# Desk       167459.93
# Phone      151722.39
# Name: TotalPrice, dtype: float64

# %%
top_product = product_sales.idxmax()
top_product_sales = product_sales.max()

print("Top-Selling Product:", top_product)
print("Total Sales:", round(top_product_sales, 2))
# Out:
# Top-Selling Product: Chair
# Total Sales: 195620.11

# %%
lowest_product = product_sales.idxmin()
lowest_product_sales = product_sales.min()

print("Lowest-Selling Product:", lowest_product)
print("Total Sales:", round(lowest_product_sales, 2))
# Out:
# Lowest-Selling Product: Phone
# Total Sales: 151722.39

# %%
product_orders = df["Product"].value_counts()

top_ordered_product = product_orders.idxmax()
top_ordered_product_count = product_orders.max()

print("Most Ordered Product:", top_ordered_product)
print("Number of Orders:", top_ordered_product_count)
# Out:
# Most Ordered Product: Printer
# Number of Orders: 181

# %%
least_ordered_product = product_orders.idxmin()
least_ordered_product_count = product_orders.min()

print("Least Ordered Product:", least_ordered_product)
print("Number of Orders:", least_ordered_product_count)
# Out:
# Least Ordered Product: Phone
# Number of Orders: 156

# %%
product_aov = df.groupby("Product")["TotalPrice"].mean().sort_values(
    ascending=False
)

print(product_aov)
# Out:
# Product
# Laptop     1110.558150
# Chair      1098.989382
# Printer    1080.732652
# Monitor    1077.616012
# Tablet     1042.284637
# Desk        985.058412
# Phone       972.579423
# Name: TotalPrice, dtype: float64

# %%
product_summary = df.groupby("Product").agg(
    Total_Orders=("OrderID", "count"),
    Total_Sales=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
).sort_values("Total_Sales", ascending=False)

product_summary
# Out:
#          Total_Orders  Total_Sales  Average_Order_Value
# Product
# Chair             178    195620.11          1098.989382
# Printer           181    195612.61          1080.732652
# Laptop            173    192126.56          1110.558150
# Tablet            179    186568.95          1042.284637
# Monitor           163    175651.41          1077.616012
# Desk              170    167459.93           985.058412
# Phone             156    151722.39           972.579423

# %%
best_aov_product = product_summary["Average_Order_Value"].idxmax()
best_aov = product_summary["Average_Order_Value"].max()

print("Product with Highest Average Order Value:", best_aov_product)
print("Average Order Value:", round(best_aov, 2))
# Out:
# Product with Highest Average Order Value: Laptop
# Average Order Value: 1110.56

# %%
lowest_aov_product = product_summary["Average_Order_Value"].idxmin()
lowest_aov = product_summary["Average_Order_Value"].min()

print("Product with Lowest Average Order Value:", lowest_aov_product)
print("Average Order Value:", round(lowest_aov, 2))
# Out:
# Product with Lowest Average Order Value: Phone
# Average Order Value: 972.58

# %%
payment_sales = df.groupby("PaymentMethod")["TotalPrice"].sum().sort_values(
    ascending=False
)

print(payment_sales)
# Out:
# PaymentMethod
# Credit Card    263847.63
# Online         262442.94
# Cash           259786.29
# Gift Card      246323.92
# Debit Card     232361.18
# Name: TotalPrice, dtype: float64

# %%
payment_orders = df["PaymentMethod"].value_counts()

most_used_payment = payment_orders.idxmax()
most_used_payment_count = payment_orders.max()

print("Most Used Payment Method:", most_used_payment)
print("Number of Orders:", most_used_payment_count)
# Out:
# Most Used Payment Method: Online
# Number of Orders: 258

# %%
payment_aov = df.groupby("PaymentMethod")["TotalPrice"].mean().sort_values(
    ascending=False
)

print(payment_aov)
# Out:
# PaymentMethod
# Credit Card    1127.553974
# Gift Card      1070.973565
# Cash           1056.041829
# Online         1017.220698
# Debit Card     1001.556810
# Name: TotalPrice, dtype: float64

# %%
status_sales = df.groupby("OrderStatus")["TotalPrice"].sum().sort_values(
    ascending=False
)

print(status_sales)
# Out:
# OrderStatus
# Cancelled    276396.21
# Pending      256328.15
# Shipped      246159.58
# Returned     243277.70
# Delivered    242600.32
# Name: TotalPrice, dtype: float64

# %%
status_orders = df["OrderStatus"].value_counts()

most_common_status = status_orders.idxmax()
most_common_status_count = status_orders.max()

print("Most Common Order Status:", most_common_status)
print("Number of Orders:", most_common_status_count)
# Out:
# Most Common Order Status: Cancelled
# Number of Orders: 250

# %%
status_aov = df.groupby("OrderStatus")["TotalPrice"].mean().sort_values(
    ascending=False
)

print(status_aov)
# Out:
# OrderStatus
# Cancelled    1105.584840
# Pending      1081.553376
# Delivered    1050.217835
# Shipped      1047.487574
# Returned      984.929960
# Name: TotalPrice, dtype: float64

# %%
referral_sales = df.groupby("ReferralSource")["TotalPrice"].sum().sort_values(
    ascending=False
)

print(referral_sales)
# Out:
# ReferralSource
# Instagram    275285.45
# Email        261808.55
# Google       250441.48
# Facebook     250410.90
# Referral     226815.58
# Name: TotalPrice, dtype: float64

# %%
referral_orders = df["ReferralSource"].value_counts()

most_used_referral = referral_orders.idxmax()
most_used_referral_count = referral_orders.max()

print("Most Used Referral Source:", most_used_referral)
print("Number of Orders:", most_used_referral_count)
# Out:
# Most Used Referral Source: Instagram
# Number of Orders: 259

# %%
referral_aov = df.groupby("ReferralSource")["TotalPrice"].mean().sort_values(
    ascending=False
)

print(referral_aov)
# Out:
# ReferralSource
# Facebook     1098.293421
# Instagram    1062.878185
# Email        1047.234200
# Google       1039.176266
# Referral     1021.691802
# Name: TotalPrice, dtype: float64

# %%
coupon_sales = df.groupby("CouponCode")["TotalPrice"].sum().sort_values(
    ascending=False
)

print(coupon_sales)
# Out:
# CouponCode
# FREESHIP    335036.99
# SAVE10      304840.02
# WINTER15    302483.54
# Name: TotalPrice, dtype: float64

# %%
coupon_orders = df["CouponCode"].value_counts()

most_used_coupon = coupon_orders.idxmax()
most_used_coupon_count = coupon_orders.max()

print("Most Used Coupon Code:", most_used_coupon)
print("Number of Orders:", most_used_coupon_count)
# Out:
# Most Used Coupon Code: FREESHIP
# Number of Orders: 313

# %%
coupon_aov = df.groupby("CouponCode")["TotalPrice"].mean().sort_values(
    ascending=False
)

print(coupon_aov)
# Out:
# CouponCode
# FREESHIP    1070.405719
# SAVE10      1065.874196
# WINTER15    1035.902534
# Name: TotalPrice, dtype: float64

# %%
payment_status = pd.crosstab(
    df["PaymentMethod"],
    df["OrderStatus"]
)

payment_status
# Out:
# OrderStatus    Cancelled  Delivered  Pending  Returned  Shipped
# PaymentMethod
# Cash                  49         45       52        57       43
# Credit Card           54         43       48        49       40
# Debit Card            44         43       55        51       39
# Gift Card             50         37       35        52       56
# Online                53         63       47        38       57

# %%
status_percentage = (
    df["OrderStatus"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

status_percentage
# Out:
# OrderStatus
# Cancelled    20.83
# Returned     20.58
# Pending      19.75
# Shipped      19.58
# Delivered    19.25
# Name: proportion, dtype: float64

# %%
payment_status.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Order Status by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Orders")
plt.xticks(rotation=0)
plt.legend(title="Order Status")
plt.grid(axis="y")
plt.show()

# %%
referral_summary = df.groupby("ReferralSource").agg(
    Total_Orders=("OrderID", "count"),
    Total_Sales=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
).sort_values("Total_Sales", ascending=False)

referral_summary
# Out:
#                 Total_Orders  Total_Sales  Average_Order_Value
# ReferralSource
# Instagram                259    275285.45          1062.878185
# Email                    250    261808.55          1047.234200
# Google                   241    250441.48          1039.176266
# Facebook                 228    250410.90          1098.293421
# Referral                 222    226815.58          1021.691802

# %%
referral_summary["Total_Sales"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Total Sales by Referral Source")
plt.xlabel("Referral Source")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
referral_orders = df["ReferralSource"].value_counts()

referral_orders.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Number of Orders by Referral Source")
plt.xlabel("Referral Source")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
referral_aov = df.groupby("ReferralSource")["TotalPrice"].mean().sort_values(
    ascending=False
)

referral_aov.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Average Order Value by Referral Source")
plt.xlabel("Referral Source")
plt.ylabel("Average Order Value")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
coupon_summary = df.groupby("CouponCode").agg(
    Total_Orders=("OrderID", "count"),
    Total_Sales=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
).sort_values("Total_Sales", ascending=False)

coupon_summary
# Out:
#             Total_Orders  Total_Sales  Average_Order_Value
# CouponCode
# FREESHIP             313    335036.99          1070.405719
# SAVE10               286    304840.02          1065.874196
# WINTER15             292    302483.54          1035.902534

# %%
coupon_summary["Total_Sales"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Total Sales by Coupon Code")
plt.xlabel("Coupon Code")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
coupon_orders = df["CouponCode"].value_counts()

coupon_orders
# Out:
# CouponCode
# FREESHIP    313
# WINTER15    292
# SAVE10      286
# Name: count, dtype: int64

# %%
coupon_status = pd.crosstab(
    df["CouponCode"],
    df["OrderStatus"]
)

coupon_status
# Out:
# OrderStatus  Cancelled  Delivered  Pending  Returned  Shipped
# CouponCode
# FREESHIP            67         61       63        61       61
# SAVE10              58         63       62        47       56
# WINTER15            67         55       53        63       54

# %%
coupon_orders.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Number of Orders by Coupon Code")
plt.xlabel("Coupon Code")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
coupon_aov = df.groupby("CouponCode")["TotalPrice"].mean().sort_values(
    ascending=False
)

coupon_aov
# Out:
# CouponCode
# FREESHIP    1070.405719
# SAVE10      1065.874196
# WINTER15    1035.902534
# Name: TotalPrice, dtype: float64

# %%
coupon_comparison = pd.DataFrame({
    "Total_Orders": coupon_orders,
    "Total_Sales": df.groupby("CouponCode")["TotalPrice"].sum()
}).sort_values("Total_Sales", ascending=False)

coupon_comparison
# Out:
#             Total_Orders  Total_Sales
# CouponCode
# FREESHIP             313    335036.99
# SAVE10               286    304840.02
# WINTER15             292    302483.54

# %%
referral_status = pd.crosstab(
    df["ReferralSource"],
    df["OrderStatus"]
)

referral_status
# Out:
# OrderStatus     Cancelled  Delivered  Pending  Returned  Shipped
# ReferralSource
# Email                  59         60       46        49       36
# Facebook               42         42       39        56       49
# Google                 58         44       47        43       49
# Instagram              41         52       69        55       42
# Referral               50         33       36        44       59

# %%
referral_status.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Order Status by Referral Source")
plt.xlabel("Referral Source")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.legend(title="Order Status")
plt.grid(axis="y")
plt.show()

# %%
product_status = pd.crosstab(
    df["Product"],
    df["OrderStatus"]
)

product_status
# Out:
# OrderStatus  Cancelled  Delivered  Pending  Returned  Shipped
# Product
# Chair               45         33       41        28       31
# Desk                35         32       38        32       33
# Laptop              35         40       30        39       29
# Monitor             35         31       29        36       32
# Phone               31         38       28        31       28
# Printer             35         29       37        38       42
# Tablet              34         28       34        43       40

# %%
product_status.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Order Status by Product")
plt.xlabel("Product")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.legend(title="Order Status")
plt.grid(axis="y")
plt.show()

# %%
payment_aov.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Average Order Value by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Average Order Value")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
status_sales.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Total Sales by Order Status")
plt.xlabel("Order Status")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
payment_sales.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Total Sales by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
product_quantity = df.groupby("Product")["Quantity"].agg(
    ["count", "mean", "median", "sum"]
).sort_values("mean", ascending=False)

product_quantity
# Out:
#          count      mean  median  sum
# Product
# Chair      178  3.157303     3.0  562
# Laptop     173  3.092486     3.0  535
# Printer    181  2.994475     3.0  542
# Desk       170  2.988235     3.0  508
# Monitor    163  2.944785     3.0  480
# Tablet     179  2.776536     3.0  497
# Phone      156  2.634615     2.0  411

# %%
product_price = df.groupby("Product")["UnitPrice"].agg(
    ["mean", "median", "min", "max"]
).sort_values("mean", ascending=False)

product_price
# Out:
#                mean   median    min     max
# Product
# Phone    375.217564  394.645  11.39  695.10
# Tablet   367.679106  401.820  17.24  699.88
# Monitor  358.663620  381.410  14.69  696.71
# Laptop   357.707052  364.140  18.20  699.93
# Chair    355.660281  384.415  14.93  695.29
# Printer  351.714917  349.400  12.10  697.19
# Desk     329.608118  320.345  26.95  697.93

# %%
product_sales_summary = df.groupby("Product").agg(
    Total_Orders=("OrderID", "count"),
    Total_Quantity=("Quantity", "sum"),
    Total_Sales=("TotalPrice", "sum")
).sort_values("Total_Sales", ascending=False)

product_sales_summary
# Out:
#          Total_Orders  Total_Quantity  Total_Sales
# Product
# Chair             178             562    195620.11
# Printer           181             542    195612.61
# Laptop            173             535    192126.56
# Tablet            179             497    186568.95
# Monitor           163             480    175651.41
# Desk              170             508    167459.93
# Phone             156             411    151722.39

# %%
cart_value_analysis = df.groupby("ItemsInCart")["TotalPrice"].agg(
    ["count", "mean", "median"]
).sort_index()

cart_value_analysis
# Out:
#              count         mean    median
# ItemsInCart
# 1               50   368.680200   416.660
# 2               78   551.362051   526.745
# 3              123   722.423008   603.630
# 4              163   831.135460   635.540
# 5              191  1055.587382   853.400
# 6              190  1119.572368   911.740
# 7              151  1157.716291   987.760
# 8              129  1488.234574  1418.650
# 9               79  1489.458101  1435.000
# 10              46  1743.218478  1742.650

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    cart_value_analysis.index,
    cart_value_analysis["mean"],
    marker="o"
)

plt.title("Average Order Value by Items in Cart")
plt.xlabel("Items in Cart")
plt.ylabel("Average Total Price")
plt.xticks(cart_value_analysis.index)
plt.grid(True)
plt.show()

# %%
quantity_value_analysis = df.groupby("Quantity")["TotalPrice"].agg(
    ["count", "mean", "median"]
).sort_index()

quantity_value_analysis
# Out:
#           count         mean   median
# Quantity
# 1           255   351.875647   359.99
# 2           240   690.540333   705.75
# 3           237  1102.431139  1144.23
# 4           251  1466.497849  1531.52
# 5           217  1750.861060  1739.60

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    quantity_value_analysis.index,
    quantity_value_analysis["mean"],
    marker="o"
)

plt.title("Average Order Value by Quantity")
plt.xlabel("Quantity")
plt.ylabel("Average Total Price")
plt.xticks(quantity_value_analysis.index)
plt.grid(True)
plt.show()

# %%
unitprice_value_analysis = df.groupby(
    pd.cut(df["UnitPrice"], bins=5)
)["TotalPrice"].agg(
    ["count", "mean", "median"]
)

unitprice_value_analysis
# Out:
#                     count         mean    median
# UnitPrice
# (10.701, 149.098]     240   234.654958   190.795
# (149.098, 286.806]    235   657.370809   612.360
# (286.806, 424.514]    237  1040.404430   973.410
# (424.514, 562.222]    253  1464.917470  1437.630
# (562.222, 699.93]     235  1858.564511  1894.920

# %%
unitprice_value_analysis["mean"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Average Total Price by Unit Price Range")
plt.xlabel("Unit Price Range")
plt.ylabel("Average Total Price")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
quantity_sales = df.groupby("Quantity")["TotalPrice"].agg(
    ["count", "sum", "mean"]
).sort_index()

quantity_sales
# Out:
#           count        sum         mean
# Quantity
# 1           255   89728.29   351.875647
# 2           240  165729.68   690.540333
# 3           237  261276.18  1102.431139
# 4           251  368090.96  1466.497849
# 5           217  379936.85  1750.861060

# %%
quantity_sales["sum"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Total Sales by Quantity")
plt.xlabel("Quantity")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
monthly_order_stats = monthly_orders.agg(
    ["min", "max", "mean"]
)

monthly_order_stats
# Out:
# min     27.0
# max     53.0
# mean    40.0
# dtype: float64

# %%
monthly_sales_stats = monthly_sales.agg(
    ["min", "max", "mean"]
)

monthly_sales_stats
# Out:
# min     27751.710
# max     68068.540
# mean    42158.732
# Name: TotalPrice, dtype: float64

# %%
monthly_aov_stats = monthly_summary["Average_Order_Value"].agg(
    ["min", "max", "mean"]
)

monthly_aov_stats
# Out:
# min      800.013469
# max     1302.792653
# mean    1051.804396
# Name: Average_Order_Value, dtype: float64

# %%
best_sales_month = monthly_sales.idxmax()
best_sales_value = monthly_sales.max()

worst_sales_month = monthly_sales.idxmin()
worst_sales_value = monthly_sales.min()

print("Highest Sales Month:", best_sales_month)
print("Highest Sales:", round(best_sales_value, 2))

print("\nLowest Sales Month:", worst_sales_month)
print("Lowest Sales:", round(worst_sales_value, 2))
# Out:
# Highest Sales Month: 2024-06
# Highest Sales: 68068.54
#
# Lowest Sales Month: 2023-04
# Lowest Sales: 27751.71

# %%
best_order_month = monthly_orders.idxmax()
best_order_count = monthly_orders.max()

worst_order_month = monthly_orders.idxmin()
worst_order_count = monthly_orders.min()

print("Highest Order Volume Month:", best_order_month)
print("Highest Number of Orders:", best_order_count)

print("\nLowest Order Volume Month:", worst_order_month)
print("Lowest Number of Orders:", worst_order_count)
# Out:
# Highest Order Volume Month: 2024-06
# Highest Number of Orders: 53
#
# Lowest Order Volume Month: 2025-01
# Lowest Number of Orders: 27

# %%
monthly_orders_sales = pd.DataFrame({
    "Total_Orders": monthly_orders,
    "Total_Sales": monthly_sales
})

monthly_orders_sales["Average_Order_Value"] = (
    monthly_orders_sales["Total_Sales"] /
    monthly_orders_sales["Total_Orders"]
)

monthly_orders_sales
# Out:
#          Total_Orders  Total_Sales  Average_Order_Value
# Date
# 2023-01            47     56685.75          1206.079787
# 2023-02            37     40117.66          1084.261081
# 2023-03            43     48609.37          1130.450465
# 2023-04            31     27751.71           895.216452
# 2023-05            49     63836.84          1302.792653
# 2023-06            45     49500.19          1100.004222
# 2023-07            44     42820.66           973.196818
# 2023-08            51     54352.14          1065.728235
# 2023-09            29     29526.67          1018.161034
# 2023-10            47     52607.85          1119.315957
# 2023-11            41     43079.67          1050.723659
# 2023-12            46     43754.73           951.189783
# 2024-01            32     38528.08          1204.002500
# 2024-02            32     36909.57          1153.424062
# 2024-03            36     36030.90          1000.858333
# 2024-04            50     49613.14           992.262800
# ...

# %%
best_aov_month = monthly_orders_sales["Average_Order_Value"].idxmax()
best_aov_value = monthly_orders_sales["Average_Order_Value"].max()

worst_aov_month = monthly_orders_sales["Average_Order_Value"].idxmin()
worst_aov_value = monthly_orders_sales["Average_Order_Value"].min()

print("Highest AOV Month:", best_aov_month)
print("Highest AOV:", round(best_aov_value, 2))

print("\nLowest AOV Month:", worst_aov_month)
print("Lowest AOV:", round(worst_aov_value, 2))
# Out:
# Highest AOV Month: 2023-05
# Highest AOV: 1302.79
#
# Lowest AOV Month: 2025-03
# Lowest AOV: 800.01

# %%
yearly_summary = df.groupby(
    df["Date"].dt.year
).agg(
    Total_Orders=("OrderID", "count"),
    Total_Sales=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
)

yearly_summary
# Out:
#       Total_Orders  Total_Sales  Average_Order_Value
# Date
# 2023           510    552643.24          1083.614196
# 2024           459    480235.87          1046.265512
# 2025           231    231882.85          1003.821861

# %%
yearly_summary["Total_Sales"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Yearly Total Sales")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
yearly_summary["Total_Orders"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Yearly Total Orders")
plt.xlabel("Year")
plt.ylabel("Number of Orders")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
yearly_summary["Average_Order_Value"].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Yearly Average Order Value")
plt.xlabel("Year")
plt.ylabel("Average Order Value")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
yearly_summary["Order_Growth_%"] = (
    yearly_summary["Total_Orders"]
    .pct_change()
    .mul(100)
    .round(2)
)

yearly_summary
# Out:
#       Total_Orders  Total_Sales  Average_Order_Value  Order_Growth_%
# Date
# 2023           510    552643.24          1083.614196             NaN
# 2024           459    480235.87          1046.265512          -10.00
# 2025           231    231882.85          1003.821861          -49.67

# %%
yearly_summary["AOV_Growth_%"] = (
    yearly_summary["Average_Order_Value"]
    .pct_change()
    .mul(100)
    .round(2)
)

yearly_summary
# Out:
#       Total_Orders  Total_Sales  Average_Order_Value  Order_Growth_%  \
# Date
# 2023           510    552643.24          1083.614196             NaN
# 2024           459    480235.87          1046.265512          -10.00
# 2025           231    231882.85          1003.821861          -49.67
#
#       AOV_Growth_%
# Date
# 2023           NaN
# 2024         -3.45
# 2025         -4.06

# %%
best_aov_year = yearly_summary["Average_Order_Value"].idxmax()
best_aov_year_value = yearly_summary["Average_Order_Value"].max()

worst_aov_year = yearly_summary["Average_Order_Value"].idxmin()
worst_aov_year_value = yearly_summary["Average_Order_Value"].min()

print("Highest AOV Year:", best_aov_year)
print("Highest AOV:", round(best_aov_year_value, 2))

print("\nLowest AOV Year:", worst_aov_year)
print("Lowest AOV:", round(worst_aov_year_value, 2))
# Out:
# Highest AOV Year: 2023
# Highest AOV: 1083.61
#
# Lowest AOV Year: 2025
# Lowest AOV: 1003.82

# %%
yearly_summary["Sales_Contribution_%"] = (
    yearly_summary["Total_Sales"]
    / yearly_summary["Total_Sales"].sum()
    * 100
).round(2)

yearly_summary
# Out:
#       Total_Orders  Total_Sales  Average_Order_Value  Order_Growth_%  \
# Date
# 2023           510    552643.24          1083.614196             NaN
# 2024           459    480235.87          1046.265512          -10.00
# 2025           231    231882.85          1003.821861          -49.67
#
#       AOV_Growth_%  Sales_Contribution_%
# Date
# 2023           NaN                 43.70
# 2024         -3.45                 37.97
# 2025         -4.06                 18.33

# %%
highest_value_order = df.loc[
    df["TotalPrice"].idxmax(),
    [
        "OrderID",
        "Date",
        "Product",
        "Quantity",
        "UnitPrice",
        "ItemsInCart",
        "TotalPrice"
    ]
]

highest_value_order
# Out:
# OrderID                  ORD200789
# Date           2023-08-17 00:00:00
# Product                     Tablet
# Quantity                         5
# UnitPrice                   691.28
# ItemsInCart                     10
# TotalPrice                  3456.4
# Name: 789, dtype: object

# %%
highest_order_value = df["TotalPrice"].max()
overall_aov = df["TotalPrice"].mean()

comparison = highest_order_value / overall_aov

print("Highest Order Value:", round(highest_order_value, 2))
print("Overall AOV:", round(overall_aov, 2))
print(
    "Highest Order is",
    round(comparison, 2),
    "times the Overall AOV"
)
# Out:
# Highest Order Value: 3456.4
# Overall AOV: 1053.97
# Highest Order is 3.28 times the Overall AOV

# %%
lowest_order_value = df["TotalPrice"].min()
overall_aov = df["TotalPrice"].mean()

comparison = overall_aov / lowest_order_value

print("Lowest Order Value:", round(lowest_order_value, 2))
print("Overall AOV:", round(overall_aov, 2))
print(
    "Overall AOV is",
    round(comparison, 2),
    "times the Lowest Order Value"
)
# Out:
# Lowest Order Value: 11.39
# Overall AOV: 1053.97
# Overall AOV is 92.53 times the Lowest Order Value

# %%
lowest_value_order = df.loc[
    df["TotalPrice"].idxmin(),
    [
        "OrderID",
        "Date",
        "Product",
        "Quantity",
        "UnitPrice",
        "ItemsInCart",
        "TotalPrice"
    ]
]

lowest_value_order
# Out:
# OrderID                  ORD201161
# Date           2023-10-16 00:00:00
# Product                      Phone
# Quantity                         1
# UnitPrice                    11.39
# ItemsInCart                      6
# TotalPrice                   11.39
# Name: 1161, dtype: object

# %%
median_price = df["TotalPrice"].median()

median_order = df.loc[
    (df["TotalPrice"] - median_price).abs().idxmin(),
    [
        "OrderID",
        "Date",
        "Product",
        "Quantity",
        "UnitPrice",
        "ItemsInCart",
        "TotalPrice"
    ]
]

print("Median Total Price:", round(median_price, 2))
print("\nOrder Closest to Median:")
print(median_order)
# Out:
# Median Total Price: 823.62
#
# Order Closest to Median:
# OrderID                  ORD200146
# Date           2025-04-30 00:00:00
# Product                     Tablet
# Quantity                         2
# UnitPrice                   411.49
# ItemsInCart                      4
# TotalPrice                  822.98
# Name: 146, dtype: object

# %%
quartile_analysis = df["TotalPrice"].quantile([0.25, 0.50, 0.75])

print("Q1 (25th Percentile):", round(quartile_analysis[0.25], 2))
print("Q2 (50th Percentile / Median):", round(quartile_analysis[0.50], 2))
print("Q3 (75th Percentile):", round(quartile_analysis[0.75], 2))
# Out:
# Q1 (25th Percentile): 410.52
# Q2 (50th Percentile / Median): 823.62
# Q3 (75th Percentile): 1578.48

# %%
df["Spending_Category"] = pd.cut(
    df["TotalPrice"],
    bins=[-float("inf"), df["TotalPrice"].quantile(0.25),
          df["TotalPrice"].quantile(0.75), float("inf")],
    labels=["Low Value", "Medium Value", "High Value"]
)

spending_summary = df["Spending_Category"].value_counts().sort_index()

print(spending_summary)
# Out:
# Spending_Category
# Low Value       301
# Medium Value    599
# High Value      300
# Name: count, dtype: int64

# %%
spending_status = pd.crosstab(
    df["Spending_Category"],
    df["OrderStatus"]
)

print(spending_status)
# Out:
# OrderStatus        Cancelled  Delivered  Pending  Returned  Shipped
# Spending_Category
# Low Value                 65         51       58        69       58
# Medium Value             118        122      117       122      120
# High Value                67         58       62        56       57

# %%
spending_status_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["OrderStatus"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_status_percentage)
# Out:
# OrderStatus        Cancelled  Delivered  Pending  Returned  Shipped
# Spending_Category
# Low Value              21.59      16.94    19.27     22.92    19.27
# Medium Value           19.70      20.37    19.53     20.37    20.03
# High Value             22.33      19.33    20.67     18.67    19.00

# %%
spending_aov = df.groupby("Spending_Category", observed=True)["TotalPrice"].mean()

print(spending_aov.round(2))
# Out:
# Spending_Category
# Low Value        214.98
# Medium Value     874.68
# High Value      2253.74
# Name: TotalPrice, dtype: float64

# %%
spending_payment = pd.crosstab(
    df["Spending_Category"],
    df["PaymentMethod"]
)

print(spending_payment)
# Out:
# PaymentMethod      Cash  Credit Card  Debit Card  Gift Card  Online
# Spending_Category
# Low Value            62           52          59         61      67
# Medium Value        125          115         122        105     132
# High Value           59           67          51         64      59

# %%
spending_payment_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["PaymentMethod"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_payment_percentage)
# Out:
# PaymentMethod       Cash  Credit Card  Debit Card  Gift Card  Online
# Spending_Category
# Low Value          20.60        17.28       19.60      20.27   22.26
# Medium Value       20.87        19.20       20.37      17.53   22.04
# High Value         19.67        22.33       17.00      21.33   19.67

# %%
spending_payment_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["PaymentMethod"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_payment_percentage)
# Out:
# PaymentMethod       Cash  Credit Card  Debit Card  Gift Card  Online
# Spending_Category
# Low Value          20.60        17.28       19.60      20.27   22.26
# Medium Value       20.87        19.20       20.37      17.53   22.04
# High Value         19.67        22.33       17.00      21.33   19.67

# %%
spending_product = pd.crosstab(
    df["Spending_Category"],
    df["Product"]
)

print(spending_product)
# Out:
# Product            Chair  Desk  Laptop  Monitor  Phone  Printer  Tablet
# Spending_Category
# Low Value             45    46      40       48     36       41      45
# Medium Value          87    87      88       70     86       90      91
# High Value            46    37      45       45     34       50      43

# %%
spending_product_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["Product"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_product_percentage)
# Out:
# Product            Chair   Desk  Laptop  Monitor  Phone  Printer  Tablet
# Spending_Category
# Low Value          14.95  15.28   13.29    15.95  11.96    13.62   14.95
# Medium Value       14.52  14.52   14.69    11.69  14.36    15.03   15.19
# High Value         15.33  12.33   15.00    15.00  11.33    16.67   14.33

# %%
spending_coupon = pd.crosstab(
    df["Spending_Category"],
    df["CouponCode"]
)

print(spending_coupon)
# Out:
# CouponCode         FREESHIP  SAVE10  WINTER15
# Spending_Category
# Low Value                66      75        78
# Medium Value            163     141       145
# High Value               84      70        69

# %%
spending_coupon_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["CouponCode"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_coupon_percentage)
# Out:
# CouponCode         FREESHIP  SAVE10  WINTER15
# Spending_Category
# Low Value             30.14   34.25     35.62
# Medium Value          36.30   31.40     32.29
# High Value            37.67   31.39     30.94

# %%
coupon_status_percentage = (
    pd.crosstab(
        df["CouponCode"],
        df["OrderStatus"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(coupon_status_percentage)
# Out:
# OrderStatus  Cancelled  Delivered  Pending  Returned  Shipped
# CouponCode
# FREESHIP         21.41      19.49    20.13     19.49    19.49
# SAVE10           20.28      22.03    21.68     16.43    19.58
# WINTER15         22.95      18.84    18.15     21.58    18.49

# %%
spending_referral_percentage = (
    pd.crosstab(
        df["Spending_Category"],
        df["ReferralSource"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(spending_referral_percentage)
# Out:
# ReferralSource     Email  Facebook  Google  Instagram  Referral
# Spending_Category
# Low Value          20.60     18.94   20.93      21.93     17.61
# Medium Value       21.37     18.03   19.20      21.54     19.87
# High Value         20.00     21.00   21.00      21.33     16.67

# %%
referral_aov_analysis = df.groupby("ReferralSource")["TotalPrice"].agg(
    ["count", "mean", "median"]
).sort_values("mean", ascending=False)

print(referral_aov_analysis.round(2))
# Out:
#                 count     mean  median
# ReferralSource
# Facebook          228  1098.29  911.52
# Instagram         259  1062.88  856.18
# Email             250  1047.23  758.19
# Google            241  1039.18  839.96
# Referral          222  1021.69  734.58

# %%
referral_aov_analysis = df.groupby("ReferralSource")["TotalPrice"].agg(
    ["count", "mean", "median"]
).sort_values("mean", ascending=False)

print(referral_aov_analysis.round(2))
# Out:
#                 count     mean  median
# ReferralSource
# Facebook          228  1098.29  911.52
# Instagram         259  1062.88  856.18
# Email             250  1047.23  758.19
# Google            241  1039.18  839.96
# Referral          222  1021.69  734.58

# %%
payment_status_percentage = (
    pd.crosstab(
        df["PaymentMethod"],
        df["OrderStatus"],
        normalize="index"
    )
    .mul(100)
    .round(2)
)

print(payment_status_percentage)
# Out:
# OrderStatus    Cancelled  Delivered  Pending  Returned  Shipped
# PaymentMethod
# Cash               19.92      18.29    21.14     23.17    17.48
# Credit Card        23.08      18.38    20.51     20.94    17.09
# Debit Card         18.97      18.53    23.71     21.98    16.81
# Gift Card          21.74      16.09    15.22     22.61    24.35
# Online             20.54      24.42    18.22     14.73    22.09

# %%
spending_status_percentage.plot(
    kind="bar",
    figsize=(15,6)
)

plt.title("Order Status Distribution by Spending Category")
plt.xlabel("Spending Category")
plt.ylabel("Percentage of Orders (%)")
plt.xticks(rotation=0)
plt.legend(title="Order Status")
plt.grid(axis="y")

plt.show()

# %%
spending_payment_percentage.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Payment Method Distribution by Spending Category")
plt.xlabel("Spending Category")
plt.ylabel("Percentage of Orders (%)")
plt.xticks(rotation=0)
plt.legend(title="Payment Method")
plt.grid(axis="y")

plt.show()

# %%
spending_referral_percentage.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Referral Source Distribution by Spending Category")
plt.xlabel("Spending Category")
plt.ylabel("Percentage of Orders (%)")
plt.xticks(rotation=0)
plt.legend(title="Referral Source")
plt.grid(axis="y")

plt.show()

# %%
final_eda_summary = pd.DataFrame({
    "Metric": [
        "Total Orders",
        "Total Sales",
        "Overall Average Order Value",
        "Median Order Value",
        "Minimum Order Value",
        "Maximum Order Value",
        "Average Quantity per Order",
        "Average Unit Price",
        "Average Items in Cart"
    ],
    "Value": [
        df["OrderID"].nunique(),
        df["TotalPrice"].sum(),
        df["TotalPrice"].mean(),
        df["TotalPrice"].median(),
        df["TotalPrice"].min(),
        df["TotalPrice"].max(),
        df["Quantity"].mean(),
        df["UnitPrice"].mean(),
        df["ItemsInCart"].mean()
    ]
})

final_eda_summary["Value"] = final_eda_summary["Value"].round(2)

print(final_eda_summary)
# Out:
#                         Metric       Value
# 0                 Total Orders     1200.00
# 1                  Total Sales  1264761.96
# 2  Overall Average Order Value     1053.97
# 3           Median Order Value      823.62
# 4          Minimum Order Value       11.39
# 5          Maximum Order Value     3456.40
# 6   Average Quantity per Order        2.95
# 7           Average Unit Price      356.41
# 8        Average Items in Cart        5.48

# %%
top_5_products = (
    df.groupby("Product")["TotalPrice"]
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

print(top_5_products.round(2))
# Out:
# Product
# Chair      195620.11
# Printer    195612.61
# Laptop     192126.56
# Tablet     186568.95
# Monitor    175651.41
# Name: TotalPrice, dtype: float64

# %%
top_5_products_by_quantity = (
    df.groupby("Product")["Quantity"]
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

print(top_5_products_by_quantity)
# Out:
# Product
# Chair      562
# Printer    542
# Laptop     535
# Desk       508
# Tablet     497
# Name: Quantity, dtype: int64

# %%
top_5_products_by_aov = (
    df.groupby("Product")["TotalPrice"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
)

print(top_5_products_by_aov.round(2))
# Out:
# Product
# Laptop     1110.56
# Chair      1098.99
# Printer    1080.73
# Monitor    1077.62
# Tablet     1042.28
# Name: TotalPrice, dtype: float64

# %%
product_performance = df.groupby("Product").agg(
    Total_Orders=("OrderID", "count"),
    Total_Quantity=("Quantity", "sum"),
    Total_Sales=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
).sort_values("Total_Sales", ascending=False)

product_performance["Average_Order_Value"] = (
    product_performance["Average_Order_Value"].round(2)
)

product_performance["Total_Sales"] = (
    product_performance["Total_Sales"].round(2)
)

print(product_performance)
# Out:
#          Total_Orders  Total_Quantity  Total_Sales  Average_Order_Value
# Product
# Chair             178             562    195620.11              1098.99
# Printer           181             542    195612.61              1080.73
# Laptop            173             535    192126.56              1110.56
# Tablet            179             497    186568.95              1042.28
# Monitor           163             480    175651.41              1077.62
# Desk              170             508    167459.93               985.06
# Phone             156             411    151722.39               972.58

# %%
best_product = product_performance["Total_Sales"].idxmax()
best_product_sales = product_performance["Total_Sales"].max()

worst_product = product_performance["Total_Sales"].idxmin()
worst_product_sales = product_performance["Total_Sales"].min()

print("Best Performing Product:", best_product)
print("Total Sales:", round(best_product_sales, 2))

print("\nLowest Performing Product:", worst_product)
print("Total Sales:", round(worst_product_sales, 2))
# Out:
# Best Performing Product: Chair
# Total Sales: 195620.11
#
# Lowest Performing Product: Phone
# Total Sales: 151722.39

# %%
highest_aov_product = product_performance["Average_Order_Value"].idxmax()
highest_aov_value = product_performance["Average_Order_Value"].max()

print("Product with Highest AOV:", highest_aov_product)
print("Highest AOV:", round(highest_aov_value, 2))
# Out:
# Product with Highest AOV: Laptop
# Highest AOV: 1110.56

# %%
lowest_aov_product = product_performance["Average_Order_Value"].idxmin()
lowest_aov_value = product_performance["Average_Order_Value"].min()

print("Product with Lowest AOV:", lowest_aov_product)
print("Lowest AOV:", round(lowest_aov_value, 2))
# Out:
# Product with Lowest AOV: Phone
# Lowest AOV: 972.58

# %%
most_ordered_product = df["Product"].value_counts().idxmax()
most_ordered_count = df["Product"].value_counts().max()

print("Most Ordered Product:", most_ordered_product)
print("Number of Orders:", most_ordered_count)
# Out:
# Most Ordered Product: Printer
# Number of Orders: 181

# %%
least_ordered_product = df["Product"].value_counts().idxmin()
least_ordered_count = df["Product"].value_counts().min()

print("Least Ordered Product:", least_ordered_product)
print("Number of Orders:", least_ordered_count)
# Out:
# Least Ordered Product: Phone
# Number of Orders: 156

# %%
highest_quantity_product = (
    df.groupby("Product")["Quantity"]
    .mean()
    .sort_values(ascending=False)
)

print(highest_quantity_product.round(2).head(5))
# Out:
# Product
# Chair      3.16
# Laptop     3.09
# Printer    2.99
# Desk       2.99
# Monitor    2.94
# Name: Quantity, dtype: float64

# %%
lowest_quantity_product = (
    df.groupby("Product")["Quantity"]
    .mean()
    .sort_values(ascending=True)
)

print(lowest_quantity_product.round(2).head(5))
# Out:
# Product
# Phone      2.63
# Tablet     2.78
# Monitor    2.94
# Desk       2.99
# Printer    2.99
# Name: Quantity, dtype: float64

# %%
product_sales_contribution = (
    df.groupby("Product")["TotalPrice"]
    .sum()
    .div(df["TotalPrice"].sum())
    .mul(100)
    .sort_values(ascending=False)
    .round(2)
)

print(product_sales_contribution)
# Out:
# Product
# Chair      15.47
# Printer    15.47
# Laptop     15.19
# Tablet     14.75
# Monitor    13.89
# Desk       13.24
# Phone      12.00
# Name: TotalPrice, dtype: float64

# %%
product_sales_contribution.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Product Sales Contribution (%)")
plt.xlabel("Product")
plt.ylabel("Sales Contribution (%)")
plt.xticks(rotation=45)
plt.grid(axis="y")

plt.show()

# %%
monthly_sales_contribution = (
    monthly_sales
    .div(monthly_sales.sum())
    .mul(100)
    .sort_values(ascending=False)
    .round(2)
)

print(monthly_sales_contribution)
# Out:
# Date
# 2024-06    5.38
# 2023-05    5.05
# 2023-01    4.48
# 2023-08    4.30
# 2025-06    4.19
# 2023-10    4.16
# 2024-04    3.92
# 2023-06    3.91
# 2023-03    3.84
# 2023-12    3.46
# 2025-05    3.43
# 2023-11    3.41
# 2024-07    3.40
# 2023-07    3.39
# 2023-02    3.17
# 2024-09    3.15
# 2025-03    3.10
# 2024-12    3.07
# 2024-01    3.05
# 2024-10    2.94
# 2024-02    2.92
# 2024-03    2.85
# 2025-02    2.79
# 2024-11    2.56
# 2024-08    2.53
# 2025-04    2.52
# 2023-09    2.33
# 2025-01    2.30
# 2024-05    2.21
# 2023-04    2.19
# Freq: M, Name: TotalPrice, dtype: float64

# %%
highest_contribution_month = monthly_sales_contribution.idxmax()
highest_contribution_value = monthly_sales_contribution.max()

lowest_contribution_month = monthly_sales_contribution.idxmin()
lowest_contribution_value = monthly_sales_contribution.min()

print("Highest Sales Contribution Month:", highest_contribution_month)
print("Sales Contribution:", highest_contribution_value, "%")

print("\nLowest Sales Contribution Month:", lowest_contribution_month)
print("Sales Contribution:", lowest_contribution_value, "%")
# Out:
# Highest Sales Contribution Month: 2024-06
# Sales Contribution: 5.38 %
#
# Lowest Sales Contribution Month: 2023-04
# Sales Contribution: 2.19 %

# %%
yearly_sales_growth = (
    yearly_summary["Total_Sales"]
    .pct_change()
    .mul(100)
    .round(2)
)

print(yearly_sales_growth)
# Out:
# Date
# 2023      NaN
# 2024   -13.10
# 2025   -51.71
# Name: Total_Sales, dtype: float64

# %%
yearly_sales_growth.dropna().plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Year-over-Year Sales Growth (%)")
plt.xlabel("Year")
plt.ylabel("Sales Growth (%)")
plt.xticks(rotation=0)
plt.axhline(0, linewidth=1)
plt.grid(axis="y")

plt.show()

# %%
yearly_order_growth = (
    yearly_summary["Total_Orders"]
    .pct_change()
    .mul(100)
    .round(2)
)
print(yearly_order_growth)
# Out:
# Date
# 2023      NaN
# 2024   -10.00
# 2025   -49.67
# Name: Total_Orders, dtype: float64

# %%
yearly_aov_growth = (
    yearly_summary["Average_Order_Value"]
    .pct_change()
    .mul(100)
    .round(2)
)

print(yearly_aov_growth)
# Out:
# Date
# 2023     NaN
# 2024   -3.45
# 2025   -4.06
# Name: Average_Order_Value, dtype: float64

# %%
best_sales_year = yearly_summary["Total_Sales"].idxmax()
best_sales_year_value = yearly_summary["Total_Sales"].max()

print("Highest Sales Year:", best_sales_year)
print("Total Sales:", round(best_sales_year_value, 2))
# Out:
# Highest Sales Year: 2023
# Total Sales: 552643.24

# %%
best_order_year = yearly_summary["Total_Orders"].idxmax()
best_order_year_count = yearly_summary["Total_Orders"].max()

print("Highest Order Volume Year:", best_order_year)
print("Number of Orders:", best_order_year_count)
# Out:
# Highest Order Volume Year: 2023
# Number of Orders: 510

# %%
worst_aov_year = yearly_summary["Average_Order_Value"].idxmin()
worst_aov_year_value = yearly_summary["Average_Order_Value"].min()

print("Lowest AOV Year:", worst_aov_year)
print("Average Order Value:", round(worst_aov_year_value, 2))
# Out:
# Lowest AOV Year: 2025
# Average Order Value: 1003.82

# %%
yearly_sales_contribution = (
    yearly_summary["Total_Sales"]
    .div(yearly_summary["Total_Sales"].sum())
    .mul(100)
    .sort_values(ascending=False)
    .round(2)
)

print(yearly_sales_contribution)

print(
    "\nHighest Sales Contribution Year:",
    yearly_sales_contribution.idxmax()
)

print(
    "Sales Contribution:",
    yearly_sales_contribution.max(),
    "%"
)
# Out:
# Date
# 2023    43.70
# 2024    37.97
# 2025    18.33
# Name: Total_Sales, dtype: float64
#
# Highest Sales Contribution Year: 2023
# Sales Contribution: 43.7 %

# %%
lowest_contribution_year = yearly_sales_contribution.idxmin()
lowest_contribution_value = yearly_sales_contribution.min()

print("Lowest Sales Contribution Year:", lowest_contribution_year)
print("Sales Contribution:", lowest_contribution_value, "%")
# Out:
# Lowest Sales Contribution Year: 2025
# Sales Contribution: 18.33 %

# %%
yearly_sales_orders = yearly_summary[
    ["Total_Orders", "Total_Sales", "Average_Order_Value"]
].copy()

print(yearly_sales_orders.round(2))
# Out:
#       Total_Orders  Total_Sales  Average_Order_Value
# Date
# 2023           510    552643.24              1083.61
# 2024           459    480235.87              1046.27
# 2025           231    231882.85              1003.82

# %%
top_10_customers = (
    df.groupby("CustomerID")["TotalPrice"]
    .agg(["count", "sum", "mean"])
    .sort_values("sum", ascending=False)
    .head(10)
)

top_10_customers.columns = [
    "Total_Orders",
    "Total_Spending",
    "Average_Order_Value"
]

print(top_10_customers.round(2))
# Out:
#             Total_Orders  Total_Spending  Average_Order_Value
# CustomerID
# C38840                 2         5723.23              2861.62
# C57276                 1         3456.40              3456.40
# C67260                 1         3390.80              3390.80
# C13877                 1         3384.90              3384.90
# C18404                 1         3370.20              3370.20
# C16775                 1         3353.75              3353.75
# C65986                 1         3352.40              3352.40
# C47778                 1         3334.00              3334.00
# C59183                 1         3322.55              3322.55
# C25276                 1         3313.90              3313.90

# %%
top_10_customers_by_orders = (
    df.groupby("CustomerID")["OrderID"]
    .count()
    .sort_values(ascending=False)
    .head(10)
)

print(top_10_customers_by_orders)
# Out:
# CustomerID
# C46651    2
# C38840    2
# C35852    2
# C21191    2
# C14847    2
# C56969    2
# C70659    2
# C91155    2
# C94569    2
# C97593    2
# Name: OrderID, dtype: int64

# %%
top_10_customers_by_aov = (
    df.groupby("CustomerID")["TotalPrice"]
    .agg(["count", "mean"])
    .sort_values("mean", ascending=False)
    .head(10)
)

top_10_customers_by_aov.columns = [
    "Total_Orders",
    "Average_Order_Value"
]

print(top_10_customers_by_aov.round(2))
# Out:
#             Total_Orders  Average_Order_Value
# CustomerID
# C57276                 1              3456.40
# C67260                 1              3390.80
# C13877                 1              3384.90
# C18404                 1              3370.20
# C16775                 1              3353.75
# C65986                 1              3352.40
# C47778                 1              3334.00
# C59183                 1              3322.55
# C25276                 1              3313.90
# C53464                 1              3299.25

# %%
top_10_customers_by_aov = (
    df.groupby("CustomerID")["TotalPrice"]
    .agg(["count", "mean"])
    .sort_values("mean", ascending=False)
    .head(10)
)

top_10_customers_by_aov.columns = [
    "Total_Orders",
    "Average_Order_Value"
]

print(top_10_customers_by_aov.round(2))
# Out:
#             Total_Orders  Average_Order_Value
# CustomerID
# C57276                 1              3456.40
# C67260                 1              3390.80
# C13877                 1              3384.90
# C18404                 1              3370.20
# C16775                 1              3353.75
# C65986                 1              3352.40
# C47778                 1              3334.00
# C59183                 1              3322.55
# C25276                 1              3313.90
# C53464                 1              3299.25

# %%
customer_analysis = df.groupby("CustomerID").agg(
    Total_Orders=("OrderID", "count"),
    Total_Spending=("TotalPrice", "sum"),
    Average_Order_Value=("TotalPrice", "mean")
).sort_values("Total_Spending", ascending=False)

print(customer_analysis.head(10).round(2))
# Out:
#             Total_Orders  Total_Spending  Average_Order_Value
# CustomerID
# C38840                 2         5723.23              2861.62
# C57276                 1         3456.40              3456.40
# C67260                 1         3390.80              3390.80
# C13877                 1         3384.90              3384.90
# C18404                 1         3370.20              3370.20
# C16775                 1         3353.75              3353.75
# C65986                 1         3352.40              3352.40
# C47778                 1         3334.00              3334.00
# C59183                 1         3322.55              3322.55
# C25276                 1         3313.90              3313.90

# %%
customer_analysis["Customer_Segment"] = pd.qcut(
    customer_analysis["Total_Spending"],
    q=3,
    labels=["Low Spender", "Medium Spender", "High Spender"]
)

customer_segment_summary = customer_analysis.groupby(
    "Customer_Segment",
    observed=True
).agg(
    Customers=("Total_Orders", "count"),
    Average_Orders=("Total_Orders", "mean"),
    Average_Spending=("Total_Spending", "mean"),
    Average_Order_Value=("Average_Order_Value", "mean")
)

print(customer_segment_summary.round(2))
# Out:
#                   Customers  Average_Orders  Average_Spending  \
# Customer_Segment
# Low Spender             397            1.00            280.64
# Medium Spender          396            1.01            854.64
# High Spender            396            1.02           2057.85
#
#                   Average_Order_Value
# Customer_Segment
# Low Spender                    280.40
# Medium Spender                 849.97
# High Spender                  2038.10

# %%
segment_counts = customer_analysis["Customer_Segment"].value_counts().sort_index()

print("Customer Segment Distribution:")
print(segment_counts)
# Out:
# Customer Segment Distribution:
# Customer_Segment
# Low Spender       397
# Medium Spender    396
# High Spender      396
# Name: count, dtype: int64

# %%
segment_counts.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Customer Distribution by Spending Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Number of Customers")
plt.xticks(rotation=0)
plt.grid(axis="y")
plt.show()

# %%
customer_order_frequency = (
    df.groupby("CustomerID")["OrderID"]
    .count()
    .value_counts()
    .sort_index()
)

print("Orders per Customer Distribution:")
print(customer_order_frequency)
# Out:
# Orders per Customer Distribution:
# OrderID
# 1    1178
# 2      11
# Name: count, dtype: int64

# %%
customer_analysis["Customer_Type"] = customer_analysis["Total_Orders"].apply(
    lambda x: "One-Time Customer" if x == 1 else "Repeat Customer"
)

customer_type_summary = customer_analysis["Customer_Type"].value_counts()

print("Customer Type Distribution:")
print(customer_type_summary)
# Out:
# Customer Type Distribution:
# Customer_Type
# One-Time Customer    1178
# Repeat Customer        11
# Name: count, dtype: int64

# %%
total_customers = len(customer_analysis)

repeat_customers = (
    customer_analysis["Customer_Type"] == "Repeat Customer"
).sum()

one_time_customers = (
    customer_analysis["Customer_Type"] == "One-Time Customer"
).sum()

repeat_customer_percentage = (
    repeat_customers / total_customers
) * 100

one_time_customer_percentage = (
    one_time_customers / total_customers
) * 100

print("Total Customers:", total_customers)
print("Repeat Customers:", repeat_customers)
print("One-Time Customers:", one_time_customers)
print("Repeat Customer Percentage:", round(repeat_customer_percentage, 2), "%")
print("One-Time Customer Percentage:", round(one_time_customer_percentage, 2), "%")
# Out:
# Total Customers: 1189
# Repeat Customers: 11
# One-Time Customers: 1178
# Repeat Customer Percentage: 0.93 %
# One-Time Customer Percentage: 99.07 %

# %%
customer_type_analysis = customer_analysis.groupby(
    "Customer_Type"
).agg(
    Customers=("Total_Orders", "count"),
    Total_Orders=("Total_Orders", "sum"),
    Total_Spending=("Total_Spending", "sum"),
    Average_Order_Value=("Average_Order_Value", "mean")
)

print(customer_type_analysis.round(2))
# Out:
#                    Customers  Total_Orders  Total_Spending  \
# Customer_Type
# One-Time Customer       1178          1178      1245226.18
# Repeat Customer           11            22        19535.78
#
#                    Average_Order_Value
# Customer_Type
# One-Time Customer              1057.07
# Repeat Customer                 887.99

# %%
plt.figure(figsize=(10, 6))

plt.hist(
    customer_analysis["Total_Spending"],
    bins=20
)

plt.title("Distribution of Customer Total Spending")
plt.xlabel("Total Spending")
plt.ylabel("Number of Customers")
plt.grid(axis="y")

plt.show()

# %%
customer_spending_stats = customer_analysis["Total_Spending"].describe()

print(customer_spending_stats.round(2))
# Out:
# count    1189.00
# mean     1063.72
# std       829.55
# min        11.39
# 25%       414.47
# 50%       834.12
# 75%      1599.85
# max      5723.23
# Name: Total_Spending, dtype: float64

# %%
high_value_threshold = customer_analysis["Total_Spending"].quantile(0.90)

high_value_customers = customer_analysis[
    customer_analysis["Total_Spending"] >= high_value_threshold
].sort_values(
    "Total_Spending",
    ascending=False
)

print("High-Value Customer Threshold:", round(high_value_threshold, 2))
print("\nNumber of High-Value Customers:", len(high_value_customers))
print("\nTop High-Value Customers:")
print(high_value_customers.head(10).round(2))
# Out:
# High-Value Customer Threshold: 2332.08
#
# Number of High-Value Customers: 119
#
# Top High-Value Customers:
#             Total_Orders  Total_Spending  Average_Order_Value  \
# CustomerID
# C38840                 2         5723.23              2861.62
# C57276                 1         3456.40              3456.40
# C67260                 1         3390.80              3390.80
# C13877                 1         3384.90              3384.90
# C18404                 1         3370.20              3370.20
# C16775                 1         3353.75              3353.75
# C65986                 1         3352.40              3352.40
# C47778                 1         3334.00              3334.00
# C59183                 1         3322.55              3322.55
# C25276                 1         3313.90              3313.90
#
#            Customer_Segment      Customer_Type
# CustomerID
# C38840         High Spender    Repeat Customer
# C57276         High Spender  One-Time Customer
# ...

# %%
high_value_sales = high_value_customers["Total_Spending"].sum()
total_customer_sales = customer_analysis["Total_Spending"].sum()

high_value_sales_percentage = (
    high_value_sales / total_customer_sales
) * 100

print("High-Value Customers Sales:", round(high_value_sales, 2))
print("Total Customer Sales:", round(total_customer_sales, 2))
print(
    "High-Value Customers Sales Contribution:",
    round(high_value_sales_percentage, 2),
    "%"
)
# Out:
# High-Value Customers Sales: 332659.38
# Total Customer Sales: 1264761.96
# High-Value Customers Sales Contribution: 26.3 %

# %%
key_observations = {
    "Overall Business": [
        "Total orders and overall sales indicate the scale of the dataset.",
        "Average Order Value helps understand the typical customer spending level."
    ],
    
    "Distribution": [
        "TotalPrice shows a positively/right-skewed distribution.",
        "High-value orders form the long right tail of the distribution."
    ],
    
    "Outliers": [
        "TotalPrice contains high-value outliers.",
        "Quantity, UnitPrice and ItemsInCart do not show IQR-based outliers."
    ],
    
    "Correlation": [
        "UnitPrice has a strong positive relationship with TotalPrice.",
        "Quantity also has a positive relationship with TotalPrice.",
        "Quantity and ItemsInCart show a moderate positive relationship."
    ],
    
    "Time Trends": [
        "Monthly orders and sales fluctuate considerably over time.",
        "June 2024 recorded the highest monthly order volume and highest monthly sales."
    ],
    
    "Customer Behaviour": [
        "Customers can be segmented into Low, Medium and High Spenders.",
        "Repeat customers can be compared with one-time customers to understand customer behaviour."
    ]
}

for category, observations in key_observations.items():
    print(f"\n--- {category} ---")
    for observation in observations:
        print("•", observation)
# Out:
# --- Overall Business ---
# • Total orders and overall sales indicate the scale of the dataset.
# • Average Order Value helps understand the typical customer spending level.
#
# --- Distribution ---
# • TotalPrice shows a positively/right-skewed distribution.
# • High-value orders form the long right tail of the distribution.
#
# --- Outliers ---
# • TotalPrice contains high-value outliers.
# • Quantity, UnitPrice and ItemsInCart do not show IQR-based outliers.
#
# --- Correlation ---
# • UnitPrice has a strong positive relationship with TotalPrice.
# • Quantity also has a positive relationship with TotalPrice.
# • Quantity and ItemsInCart show a moderate positive relationship.
#
# --- Time Trends ---
# • Monthly orders and sales fluctuate considerably over time.
# • June 2024 recorded the highest monthly order volume and highest monthly sales.
#
# --- Customer Behaviour ---
# • Customers can be segmented into Low, Medium and High Spenders.
# ...

# %%
final_summary = pd.DataFrame({
    "Metric": [
        "Total Orders",
        "Total Sales",
        "Average Order Value",
        "Median Order Value",
        "Minimum Order Value",
        "Maximum Order Value",
        "Average Quantity per Order",
        "Average Unit Price",
        "Average Items in Cart"
    ],
    
    "Value": [
        df["OrderID"].nunique(),
        df["TotalPrice"].sum(),
        df["TotalPrice"].mean(),
        df["TotalPrice"].median(),
        df["TotalPrice"].min(),
        df["TotalPrice"].max(),
        df["Quantity"].mean(),
        df["UnitPrice"].mean(),
        df["ItemsInCart"].mean()
    ]
})

final_summary["Value"] = final_summary["Value"].round(2)

print(final_summary)
# Out:
#                        Metric       Value
# 0                Total Orders     1200.00
# 1                 Total Sales  1264761.96
# 2         Average Order Value     1053.97
# 3          Median Order Value      823.62
# 4         Minimum Order Value       11.39
# 5         Maximum Order Value     3456.40
# 6  Average Quantity per Order        2.95
# 7          Average Unit Price      356.41
# 8       Average Items in Cart        5.48

# %%
print("========== FINAL EDA KEY OBSERVATIONS ==========\n")

print("1. BUSINESS OVERVIEW")
print(f"• Total Orders: {df['OrderID'].nunique()}")
print(f"• Total Sales: ₹{df['TotalPrice'].sum():,.2f}")
print(f"• Overall Average Order Value: ₹{df['TotalPrice'].mean():,.2f}")

print("\n2. ORDER VALUE DISTRIBUTION")
print(f"• Median Order Value: ₹{df['TotalPrice'].median():,.2f}")
print(f"• Minimum Order Value: ₹{df['TotalPrice'].min():,.2f}")
print(f"• Maximum Order Value: ₹{df['TotalPrice'].max():,.2f}")
print("• TotalPrice is positively/right-skewed, with a long high-value tail.")

print("\n3. OUTLIER ANALYSIS")
print("• TotalPrice contains high-value outliers.")
print("• Quantity, UnitPrice and ItemsInCart have no IQR-based outliers.")

print("\n4. CORRELATION")
print("• UnitPrice has a strong positive relationship with TotalPrice.")
print("• Quantity has a moderate positive relationship with TotalPrice.")
print("• Quantity and ItemsInCart have a moderate positive relationship.")

print("\n5. TIME TREND")
print("• Monthly orders and sales fluctuate over time.")
print("• June 2024 recorded the highest monthly order volume: 53 orders.")
print("• June 2024 also recorded the highest monthly sales: ₹68,068.54.")

print("\n6. CUSTOMER ANALYSIS")
print("• Customers were segmented into Low, Medium and High Spenders.")
print("• One-time and repeat customers were compared based on orders and spending.")
print("• High-value customers were identified using the 90th percentile spending threshold.")

print("\n========== END OF EDA ==========")
# Out:
# ========== FINAL EDA KEY OBSERVATIONS ==========
#
# 1. BUSINESS OVERVIEW
# • Total Orders: 1200
# • Total Sales: ₹1,264,761.96
# • Overall Average Order Value: ₹1,053.97
#
# 2. ORDER VALUE DISTRIBUTION
# • Median Order Value: ₹823.62
# • Minimum Order Value: ₹11.39
# • Maximum Order Value: ₹3,456.40
# • TotalPrice is positively/right-skewed, with a long high-value tail.
#
# 3. OUTLIER ANALYSIS
# • TotalPrice contains high-value outliers.
# • Quantity, UnitPrice and ItemsInCart have no IQR-based outliers.
#
# 4. CORRELATION
# • UnitPrice has a strong positive relationship with TotalPrice.
# • Quantity has a moderate positive relationship with TotalPrice.
# • Quantity and ItemsInCart have a moderate positive relationship.
#
# 5. TIME TREND
# • Monthly orders and sales fluctuate over time.
# • June 2024 recorded the highest monthly order volume: 53 orders.
# • June 2024 also recorded the highest monthly sales: ₹68,068.54.
#
# 6. CUSTOMER ANALYSIS
# ...

# %%
print("""
==================== PROJECT CONCLUSION ====================

The Exploratory Data Analysis provided useful insights into order,
sales, customer and product behaviour.

Key findings:
• The dataset contains 1,200 orders with total sales of ₹12,64,761.96.
• The overall Average Order Value is ₹1,053.97.
• TotalPrice is positively skewed, indicating a relatively small number
  of high-value orders.
• TotalPrice contains high-value outliers, while Quantity, UnitPrice
  and ItemsInCart do not contain IQR-based outliers.
• UnitPrice has a strong positive relationship with TotalPrice,
  while Quantity has a moderate positive relationship with TotalPrice.
• Monthly orders and sales fluctuate over time rather than showing
  a consistent long-term upward or downward trend.
• June 2024 recorded the highest monthly order volume with 53 orders
  and the highest monthly sales of ₹68,068.54.
• Customer analysis revealed differences between one-time, repeat,
  low-spending, medium-spending and high-spending customers.

Overall, the analysis demonstrates how descriptive statistics,
outlier detection, correlation analysis, customer analysis and
time-based analysis can be used to understand business performance
and identify meaningful patterns in transactional data.

==================== END OF PROJECT 2 ====================
""")
# Out:
# ==================== PROJECT CONCLUSION ====================
#
# The Exploratory Data Analysis provided useful insights into order,
# sales, customer and product behaviour.
#
# Key findings:
# • The dataset contains 1,200 orders with total sales of ₹12,64,761.96.
# • The overall Average Order Value is ₹1,053.97.
# • TotalPrice is positively skewed, indicating a relatively small number
#   of high-value orders.
# • TotalPrice contains high-value outliers, while Quantity, UnitPrice
#   and ItemsInCart do not contain IQR-based outliers.
# • UnitPrice has a strong positive relationship with TotalPrice,
#   while Quantity has a moderate positive relationship with TotalPrice.
# • Monthly orders and sales fluctuate over time rather than showing
#   a consistent long-term upward or downward trend.
# • June 2024 recorded the highest monthly order volume with 53 orders
#   and the highest monthly sales of ₹68,068.54.
# • Customer analysis revealed differences between one-time, repeat,
# ...
